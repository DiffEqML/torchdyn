# %% [markdown]
# # Trajectory Tracking with Integral Loss

# %%
import sys
sys.path.append('../')
from torchdyn.models import *; from torchdyn import *

# %% [markdown]
# ## Integral Loss
#
# We consider a loss of type
#
# $$
#     \ell_\theta := \int_0^S g(h(s))d\tau
# $$
#
# where $h(s)$ satisfies the neural ODE initial value problem
#
# $$
#     \left\{
#     \begin{aligned}
#         \dot{h}(s) &= f(h(s), \theta(s))\\
#         h(0) &= x
#     \end{aligned}
#     \right. \quad s\in[0,S]
# $$
#
# where $\theta(s)$ is parametrized with some spectral method (`Galerkin-style`),  i.e. $\theta(s)=\theta(s,\omega)$ [$\omega$: parameters of $\theta(s)$].
#
# **REMARK:** In `torchdyn`, we do not need to evaluate the following integral in the formard pass of the ODE integration.
# In fact, we will compute the gradient $d\ell/d\omega$ just by solving backward
#
# $$
#     \begin{aligned}
#         \dot\lambda (s) &= -\frac{\partial f}{\partial h}\lambda(s) + \frac{\partial g}{\partial h} \\
#         \dot\mu (s) &= -\frac{\partial f}{\partial \theta}\frac{\partial \theta}{\partial \omega}\lambda(s)
#     \end{aligned}~~\text{with}~~
#     \begin{aligned}
#         \lambda (S) &= 0\\
#         \mu (S) &= 0
#     \end{aligned}
# $$
#
# and, $\frac{d\ell}{d\omega} = \mu(0)$. Check out [this paper](https://arxiv.org/abs/2003.08063) for more details on the integral adjoint for neural ODEs.

# %% [markdown]
# **Example:** Use a neural ODE to track a 2D curve $\gamma:[0,\infty]\rightarrow \mathbb{S}_2$ ($\mathbb{S}_2$: unit circle, $\mathbb{S}_2:=\{x\in\mathbb{R}^2:||x||_2=1\}$), i.e.
#
# $$
#     \gamma(s) := [\cos(2\pi s), \sin(2\pi s)]
# $$
#
# which has periodicity equal to $1$: $\forall n\in\mathbb{N}, \forall s\in[0,\infty]~~\gamma(s) = \gamma(ns)$.
#
# Let suppose to train the neural ODE for $s\in[0,1]$. Therefore we can easily setup the integral cost as
#
# $$
#     \ell_\theta := \int_0^1 ||h(\tau)-\gamma(\tau)||_2^2 d\tau
# $$

# %%
class intloss(nn.Module):
    def __init__(self):
        super().__init__()
        
    def y(self, s):
        return torch.tensor([torch.cos(2*np.pi*s), torch.sin(2*np.pi*s)]).to(device)
        
    def forward(self, s, x):
        return (torch.norm(self.y(s)-x, p=2, dim=1)**2)

# %% [markdown]
# **Note:** In this case we do not define any dataset of initial conditions and load it into the dataloader. Instead, at each step, we will sample new ICs from a normal distrubution centered in $\gamma(0) = [1,0]$
#
# $$
#     x_t \sim \mathcal{N}(\gamma(0),0.1)
# $$
#
# However, we still need to define a "dummy" `trainloader` to "trick" `pythorch_lightning`'s API.

# %%
# dummy trainloader
train = torch.utils.data.TensorDataset(torch.zeros(1), torch.zeros(1))
trainloader = torch.utils.data.DataLoader(train, batch_size=1, shuffle=False)

# %% [markdown]
# **Learner**

# %%
import torch
import torch.nn as nn
import pytorch_lightning as pl
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

class Learner(pl.LightningModule):
    def __init__(self, model:nn.Module, settings:dict={}):
        super().__init__()
        self.model = model
        
    def forward(self, x):
        return self.model(x)    
    
    def training_step(self, batch, batch_idx):    
        # We sample from Normal distribution around "nominal" initial condition
        x = torch.tensor([1.,0.])
        x = x + 0.1*torch.randn(2048,2)
        y_hat = self.model(x.to(device))
        # We need to evaluate a "dummy loss" (just the summed output of the model)
        # to construct the graph for the 'backward()' "triggering" the integral adjoint 
        loss = 0.*y_hat.sum()
        print("%s" % y_hat.mean(0))
        tensorboard_logs = {'train_loss': loss}
        # At traing we expect `loss` to be 1
        return {'loss': loss, 'log': tensorboard_logs}   
    
    def configure_optimizers(self):
        return torch.optim.RMSprop(self.model.parameters(), lr=0.001)

    def train_dataloader(self):
        return trainloader

# %% [markdown]
# ## Parameter Varying Neural ODE

# %%
class Stable(nn.Module):
    """Stable Neural Flow"""
    def __init__(self, net, depthvar=False, controlled=False):
        super().__init__()
        self.net, self.depthvar, self.controlled = net, depthvar, controlled
        self.Ms = torch.nn.Parameter(torch.randn(1,2)).to(device)
        self.Ma = torch.nn.Parameter(torch.randn(2,2)).to(device)
    
    def Askew(self):
        return .5*(self.Ma - self.Ma.T)
    
    def Asym(self):
        return .5*(self.Ms + self.Ms.T)

    def forward(self, x):
        with torch.set_grad_enabled(True):
            bs, n = x.shape[0], x.shape[1] // 2
            x = x.requires_grad_(True)
            eps = self.net(x).sum()
            out = -torch.autograd.grad(eps, x, allow_unused=False, create_graph=True)[0] 
            #self.out = out
        out = out[:,:-1] if self.depthvar else out
        out = out[:,:-2] if self.controlled else out
        return out @ self.Askew()

# %% [markdown]
# **Model**

# %%
# We use a Galerkin neural ODE with one hidden layer, 
# Fourier spectrum (period=1) and only two freq.s
net = nn.Sequential(DepthCat(1),
                  GalLinear(2, 64, 
                            FourierExpansion, 
                            n_harmonics=2,
                            dilation=False,
                            shift=False),
                  nn.Tanh(),
                  nn.Linear(64,1))

# net = nn.Sequential(nn.Linear(2,64),
#                   nn.Tanh(),
#                   nn.Linear(64,2))

f = Stable(net)

# Define the model
model = NeuralDE(f, 
                 solver='rk4',
                 sensitivity='adjoint',
                 atol=1e-6,
                 rtol=1e-5,
                 s_span=torch.linspace(0,1,25),
                 intloss=intloss()).to(device)

# %%
# Train the model
learn = Learner(model)
trainer = pl.Trainer(min_epochs=1000, max_epochs=1500)
trainer.fit(learn)
# Out:
# GPU available: True, used: False
# TPU available: False, using: 0 TPU cores
#
#   | Name  | Type     | Params
# -----------------------------------
# 0 | model | NeuralDE | 833
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Training', layout=Layout(flex='2'), max…
# tensor([0.9665, 0.0275], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([0.7644, 0.0395], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 0.6464, -0.0063], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 0.5490, -0.0572], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 0.4704, -0.1205], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 0.3835, -0.1828], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 0.3147, -0.2445], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 0.2433, -0.3060], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 0.1846, -0.3660], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 0.1351, -0.4194], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 0.0873, -0.4701], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 0.0548, -0.5075], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 0.0277, -0.5477], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 0.0077, -0.5827], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([-0.0095, -0.6007], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([-0.0224, -0.6208], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([-0.0291, -0.6392], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([-0.0352, -0.6530], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([-0.0416, -0.6610], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([-0.0381, -0.6811], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([-0.0442, -0.6801], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([-0.0377, -0.6861], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([-0.0369, -0.6935], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([-0.0368, -0.6981], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([-0.0358, -0.7105], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([-0.0336, -0.7062], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([-0.
device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3577, -0.5463], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3566, -0.4941], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3599, -0.5532], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3572, -0.4948], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3619, -0.5439], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3595, -0.4963], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3660, -0.5103], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3563, -0.5256], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3675, -0.4965], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3582, -0.5100], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3647, -0.4972], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3586, -0.5113], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3731, -0.5121], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3603, -0.4680], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3699, -0.5122], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3648, -0.4825], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3730, -0.5085], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3652, -0.4676], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3676, -0.4966], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3671, -0.4887], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3747, -0.4612], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3652, -0.5107], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3774, -0.4310], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3698, -0.5320], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3763, -0.3960], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3652, -0.5380], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3815, -0.3991], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3627, -0.5321], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3836, -0.3946], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3589, -0.5184], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3882, -0.3968], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3617, -0.5075], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3833, -0.4168], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3721, -0.4794], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3793, -0.4210], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3735, -0.4790], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3860, -0.4024], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3742, -0.4941], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3814, -0.3697], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3766, -0.5024], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3835, -0.3696], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3765, -0.4781], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3885, -0.3912], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3764, -0.4729], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3897, -0.3821], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3686, -0.4555], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3946, -0.3842], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3727, -0.4626], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3929, -0.3691], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3748, -0.4626], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3939, -0.3717], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3720, -0.4369], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3985, -0.3869], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3763, -0.4334], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3934, -0.3718], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3812, -0.4338], device='cuda:0', grad_fn=<MeanBackward1>)
# tensor([ 1.3901, -0.3563], device='cuda:0', grad_fn=<MeanBackward1>)

# %% [markdown]
# **Plots**
#
# We first evaluate the model on a test set of initial conditions sampled from $\mathcal{N}(\gamma(0),\sigma\mathbb{I})$. Since we trained the neural ODE with $\sigma=0.1$, now we test it with $\sigma=0.2$.

# %%
s_span = torch.linspace(0, 5, 100)
x_test = torch.tensor([1.,0.])
x_test = x_test + 0.2*torch.randn(100, 2)
trajectory = model.trajectory(x_test.to(device), s_span).detach().cpu()

# %% [markdown]
# **Depth evolution of the system** -> The system is trained for $s\in[0,1]$ and then we extrapolate until $s=5$

# %%
y1 = np.cos(2*np.pi*s_span)
y2 = np.sin(2*np.pi*s_span)

fig = plt.figure(figsize=(8,3))
ax = fig.add_subplot(111)
ax.scatter(s_span[:100], y1[:100], color='orange',alpha=0.5)
ax.scatter(s_span[:100], y2[:100], color='orange',alpha=0.5)
ax.scatter(s_span[100:], y1[100:], color='red',alpha=0.5)
ax.scatter(s_span[100:], y2[100:], color='red',alpha=0.5)
for i in range(len(x_test)):
    ax.plot(s_span, trajectory[:,i,:], color='blue', alpha=.1)
ax.set_xlabel(r"$s$ [depth]")
ax.set_ylabel(r"$h(s)$ [state]")
ax.set_title(r"Depth evolution of the system");

# %% [markdown]
# **State-space trajectories**
# -> All the (random) IC converge to the desired trajectory

# %%
fig = plt.figure(figsize=(3,3))
ax = fig.add_subplot(111)
for i in range(len(x_test)):
    ax.plot(trajectory[:,i,0], trajectory[:,i,1], color='blue', alpha=.1)
    ax.scatter(trajectory[0,i,0], trajectory[0,i,1], color='black', alpha=.1)
ax.plot(y1[:100],y2[:100], color='red')
ax.set_xlabel(r"$h_0$")
ax.set_ylabel(r"$h_1$")
ax.set_title(r"State-Space Trajectories");
