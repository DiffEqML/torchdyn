# %%
import torchdyn
import torch
import torch.nn as nn
import matplotlib.pyplot as plt
from torchdyn.numerics import Euler, RungeKutta4, Tsitouras45, DormandPrince45
from torchdyn.numerics import odeint

import torchdiffeq
import time 
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
class VanDerPol(nn.Module):
    def __init__(self, alpha=10):
        super().__init__()
        self.alpha = alpha
        self.nfe = 0

    def forward(self, t, z):
        self.nfe += 1
        x1, x2 = z[...,:1], z[...,1:2]
        return torch.cat([x2, self.alpha * (1 - x1**2) * x2 - x1], -1)

# %%
f = VanDerPol()
x = torch.randn(1024, 2)
t_span = torch.linspace(0, 5, 400)

# %% [markdown]
# #### Fixed--step bench

# %%
t0 = time.time()
t_eval, sol1 = odeint(f, x, t_span, solver='rk4')
t_end1 = time.time() - t0
print(t_end1)

t0 = time.time()
sol2 = torchdiffeq.odeint(f, x, t_span, method='rk4')
t_end2 = time.time() - t0
print(t_end2)

true_sol = torchdiffeq.odeint(f, x, t_span, method='dopri5', atol=1e-9, rtol=1e-9)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-178-5f0d8e228d1a> in <module>
#       1 t0 = time.time()
# ----> 2 t_eval, sol1 = odeint(f, x, t_span, solver='rk4')
#       3 t_end1 = time.time() - t0
#       4 print(t_end1)
#       5
#
# ~/libraries/torchdyn/torchdyn/numerics/odeint.py in odeint(f, x, t_span, solver, atol, rtol)
#      22         elif len(t_span.shape) == 1:
#      23                 if stepping_class == 'fixed':
# ---> 24                         return fixed_odeint(f, x, t_span, solver)
#      25                 elif stepping_class == 'adaptive':
#      26                         return adaptive_odeint(f, x, t_span, solver, atol, rtol)
#
# ~/libraries/torchdyn/torchdyn/numerics/odeint.py in fixed_odeint(f, x, t_span, solver)
#      91                 sol.append(x)
#      92                 t = t + dt
# ---> 93                 dt = t_span[steps] - t
#      94                 steps += 1
#      95         return t_span, torch.stack(sol)
#
# IndexError: index 400 is out of bounds for dimension 0 with size 400

# %%
sol1.shape
# Out:
# torch.Size([400, 1024, 2])

# %%
plt.plot((sol1-true_sol).abs().mean(1), c='black')
plt.plot((sol2-true_sol).abs().mean(1), c='red')
# Out:
# [<matplotlib.lines.Line2D at 0x7fd17757c370>,
#  <matplotlib.lines.Line2D at 0x7fd17757c610>]

# %%
plt.plot(sol1[:,0])
plt.plot(sol2[:,0])
# Out:
# [<matplotlib.lines.Line2D at 0x7fd1771a8730>,
#  <matplotlib.lines.Line2D at 0x7fd1771a8820>]

# %% [markdown]
# #### Adaptive-step bench

# %%
t0 = time.time()
t_eval, sol1 = odeint(f, x, t_span, solver='dopri5', atol=1e-4, rtol=1e-4)
t_end1 = time.time() - t0
print(t_end1)

t0 = time.time()
sol2 = torchdiffeq.odeint(f, x, t_span, method='dopri5', atol=1e-4, rtol=1e-4)
t_end2 = time.time() - t0
print(t_end2)

true_sol = torchdiffeq.odeint(f, x, t_span, method='dopri5', atol=1e-9, rtol=1e-9)
# Out:
# 0.25615477561950684
# 0.19269275665283203

# %%
plt.plot((sol1-true_sol).abs().mean(1), c='black')
plt.plot((sol2-true_sol).abs().mean(1), c='red')
# Out:
# [<matplotlib.lines.Line2D at 0x7fd1772a10d0>,
#  <matplotlib.lines.Line2D at 0x7fd1772a11c0>]
